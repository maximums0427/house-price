# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix
from sklearn.preprocessing import StandardScaler
from sklearn import cross_validation
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.grid_search import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error
from scipy.stats.stats import pearsonr

# %%
train_dataset = pd.read_csv(
'data/train.csv')
test_dataset = pd.read_csv(
'data/test.csv')

# %%
dataset = train_dataset.append(test_dataset)

# %%
f_name = 'LotConfig'
def feature_analysis(f_name):
    print('There are {} missing values in this column.'
          .format(train_dataset[f_name].isnull().sum()))
    #print(set(train_dataset['MSZoning']))
    print(test_dataset[f_name].value_counts(normalize=False))
    grps = list(test_dataset[f_name].value_counts(normalize=False).index)
    f_to_plot = []
    for i in grps:
        f_to_plot.append(train_dataset['SalePrice'][train_dataset[f_name]==i])
    fig = plt.figure(1, figsize=(9, 6))

    # Create an axes instance
    ax = fig.add_subplot(111)

    # Create the boxplot
    bp = ax.boxplot(f_to_plot)
    plt.show()
    
    for i in grps:
        train_dataset['SalePrice'][train_dataset[f_name]==i].plot(kind='density',label=i)
    plt.legend()
    plt.show()
feature_analysis(f_name)
# Out:
# There are 0 missing values in this column.
# Inside     1081
# Corner      248
# CulDSac      82
# FR2          38
# FR3          10
# Name: LotConfig, dtype: int64

# %%
dataset.tail()['SalePrice']
# Out:
# 1454   NaN
# 1455   NaN
# 1456   NaN
# 1457   NaN
# 1458   NaN
# Name: SalePrice, dtype: float64

# %%
train_dataset['MSSubClass'].isnull().values.any()
#buf = train_dataset[['MSSubClass','SalePrice']]
MSSubClass_20 = train_dataset['SalePrice'][train_dataset['MSSubClass']==20]
MSSubClass_30 = train_dataset['SalePrice'][train_dataset['MSSubClass']==30]
MSSubClass_40 = train_dataset['SalePrice'][train_dataset['MSSubClass']==40]
MSSubClass_45 = train_dataset['SalePrice'][train_dataset['MSSubClass']==45]
MSSubClass_50 = train_dataset['SalePrice'][train_dataset['MSSubClass']==50]
MSSubClass_60 = train_dataset['SalePrice'][train_dataset['MSSubClass']==60]
MSSubClass_70 = train_dataset['SalePrice'][train_dataset['MSSubClass']==70]
MSSubClass_75 = train_dataset['SalePrice'][train_dataset['MSSubClass']==75]
MSSubClass_80 = train_dataset['SalePrice'][train_dataset['MSSubClass']==80]
MSSubClass_85 = train_dataset['SalePrice'][train_dataset['MSSubClass']==85]
MSSubClass_90 = train_dataset['SalePrice'][train_dataset['MSSubClass']==90]
MSSubClass_120 = train_dataset['SalePrice'][train_dataset['MSSubClass']==120]
MSSubClass_150 = train_dataset['SalePrice'][train_dataset['MSSubClass']==150]
MSSubClass_160 = train_dataset['SalePrice'][train_dataset['MSSubClass']==160]
MSSubClass_180 = train_dataset['SalePrice'][train_dataset['MSSubClass']==180]
MSSubClass_190 = train_dataset['SalePrice'][train_dataset['MSSubClass']==190]

MSSubClass_to_plot = [MSSubClass_20,MSSubClass_30,MSSubClass_40,MSSubClass_45,
                      MSSubClass_50,MSSubClass_60,MSSubClass_70,MSSubClass_75,
                      MSSubClass_80,MSSubClass_85,MSSubClass_90,MSSubClass_120,
                      MSSubClass_150,MSSubClass_160,MSSubClass_180,MSSubClass_190]

# Create a figure instance
fig = plt.figure(1, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(MSSubClass_to_plot)

#plt.show()

# %%
#MSZoning
print(train_dataset['MSZoning'].isnull().values.any())
#print(set(train_dataset['MSZoning']))
print(train_dataset['MSZoning'].value_counts(normalize=True))
MSZoning_C = train_dataset['SalePrice'][train_dataset['MSZoning']=='C (all)']
MSZoning_FV = train_dataset['SalePrice'][train_dataset['MSZoning']=='FV']
MSZoning_RH = train_dataset['SalePrice'][train_dataset['MSZoning']=='RH']
MSZoning_RL = train_dataset['SalePrice'][train_dataset['MSZoning']=='RL']
MSZoning_RM = train_dataset['SalePrice'][train_dataset['MSZoning']=='RM']

MSZoning_to_plot = [MSZoning_C,MSZoning_FV,MSZoning_RH,MSZoning_RL,
                    MSZoning_RM]
# Create a figure instance
fig = plt.figure(1, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(MSZoning_to_plot)
# Out:
# False
# RL         0.788356
# RM         0.149315
# FV         0.044521
# RH         0.010959
# C (all)    0.006849
# dtype: float64

# %%
print(train_dataset['LotFrontage'].isnull().values.any())
print(train_dataset['LotFrontage'].isnull().sum())
#print(train_dataset['LotFrontage'].value_counts(normalize=True))
plt.scatter(train_dataset['LotFrontage'],train_dataset['SalePrice'])
plt.xlabel('LotFrontage')
plt.ylabel('Price')
plt.show()
print(train_dataset[['LotFrontage','SalePrice']].corr())
# Out:
# True
# 259
#              LotFrontage  SalePrice
# LotFrontage     1.000000   0.351799
# SalePrice       0.351799   1.000000

# %%
train_dataset['LotFrontage'].hist(bins=20)
plt.show()

# %%
print('There are {} missing values in this column.'
      .format(train_dataset['LotArea'].isnull().sum()))
plt.scatter(train_dataset['LotArea'],train_dataset['SalePrice'])
print(train_dataset[['LotArea','SalePrice']].corr())
# Out:
# There are 0 missing values in this column.
#             LotArea  SalePrice
# LotArea    1.000000   0.263843
# SalePrice  0.263843   1.000000

# %%
print('There are {} missing values in this column.'
      .format(train_dataset['Street'].isnull().sum()))
#print(set(train_dataset['MSZoning']))
print(train_dataset['Street'].value_counts(normalize=False))
Street_G = train_dataset['SalePrice'][train_dataset['Street']=='Grvl']
Street_P = train_dataset['SalePrice'][train_dataset['Street']=='Pave']


Street_to_plot = [Street_G, Street_P]
# Create a figure instance
fig = plt.figure(1, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(Street_to_plot)
# Out:
# There are 0 missing values in this column.
# Pave    1454
# Grvl       6
# dtype: int64

# %%
print('There are {} missing values in this column.'
      .format(train_dataset['LotShape'].isnull().sum()))
#print(set(train_dataset['MSZoning']))
print(train_dataset['LotShape'].value_counts(normalize=False))

LotShape_Reg = train_dataset['SalePrice'][train_dataset['LotShape']=='Reg']
LotShape_IR1 = train_dataset['SalePrice'][train_dataset['LotShape']=='IR1']
LotShape_IR2 = train_dataset['SalePrice'][train_dataset['LotShape']=='IR2']
LotShape_IR3 = train_dataset['SalePrice'][train_dataset['LotShape']=='IR3']


LotShape_to_plot = [LotShape_Reg, LotShape_IR1, LotShape_IR2, LotShape_IR3]
# Create a figure instance
fig = plt.figure(1, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(LotShape_to_plot)
plt.show()
train_dataset['SalePrice'][train_dataset['LotShape']=='Reg'].plot(kind='density',label="Reg")
train_dataset['SalePrice'][train_dataset['LotShape']=='IR1'].plot(kind='density',label="IR1")
train_dataset['SalePrice'][train_dataset['LotShape']=='IR2'].plot(kind='density',label="IR2")
train_dataset['SalePrice'][train_dataset['LotShape']=='IR3'].plot(kind='density',label="IR3")
plt.legend()
plt.show()
# Out:
# There are 0 missing values in this column.
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# dtype: int64

# %%
print('There are {} missing values in this column.'
      .format(train_dataset['LandContour'].isnull().sum()))
#print(set(train_dataset['MSZoning']))
print(train_dataset['LandContour'].value_counts(normalize=False))

LandContour_Lvl = train_dataset['SalePrice'][train_dataset['LandContour']=='Lvl']
LandContour_Bnk = train_dataset['SalePrice'][train_dataset['LandContour']=='Bnk']
LandContour_HLS = train_dataset['SalePrice'][train_dataset['LandContour']=='HLS']
LandContour_Low = train_dataset['SalePrice'][train_dataset['LandContour']=='Low']


LotShape_to_plot = [LandContour_Lvl, LandContour_Bnk, LandContour_HLS, LandContour_Low]
# Create a figure instance
fig = plt.figure(1, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(LotShape_to_plot)
plt.show()
train_dataset['SalePrice'][train_dataset['LandContour']=='Lvl'].plot(kind='density',label="Reg")
train_dataset['SalePrice'][train_dataset['LandContour']=='Bnk'].plot(kind='density',label="IR1")
train_dataset['SalePrice'][train_dataset['LandContour']=='Low'].plot(kind='density',label="IR2")
train_dataset['SalePrice'][train_dataset['LandContour']=='HLS'].plot(kind='density',label="IR3")
plt.legend()
plt.show()
# Out:
# There are 0 missing values in this column.
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# dtype: int64

# %%
print('There are {} missing values in this column.'
      .format(train_dataset['Utilities'].isnull().sum()))
#print(set(train_dataset['MSZoning']))
print(test_dataset['Utilities'].value_counts(normalize=False))
# Out:
# There are 0 missing values in this column.
# AllPub    1457
# dtype: int64

# %%
print('There are {} missing values in this column.'
      .format(train_dataset['LotConfig'].isnull().sum()))
#print(set(train_dataset['MSZoning']))
print(test_dataset['LotConfig'].value_counts(normalize=False))
# Out:
# There are 0 missing values in this column.
# Inside     1081
# Corner      248
# CulDSac      82
# FR2          38
# FR3          10
# dtype: int64

# %%
f_name = 'LotConfig'
def feature_analysis(f_name):
    print('There are {} missing values in this column.'
          .format(train_dataset[f_name].isnull().sum()))
    #print(set(train_dataset['MSZoning']))
    print(test_dataset[f_name].value_counts(normalize=False))
    grps = list(test_dataset[f_name].value_counts(normalize=False).index)
    f_to_plot = []
    for i in grps:
        f_to_plot.append(train_dataset['SalePrice'][train_dataset[f_name]==i])
    fig = plt.figure(1, figsize=(9, 6))

    # Create an axes instance
    ax = fig.add_subplot(111)

    # Create the boxplot
    bp = ax.boxplot(f_to_plot)
    plt.show()
    
    for i in grps:
        train_dataset['SalePrice'][train_dataset[f_name]==i].plot(kind='density',label=i)
    plt.legend()
    plt.show()
feature_analysis(f_name)
# Out:
# There are 0 missing values in this column.
# Inside     1081
# Corner      248
# CulDSac      82
# FR2          38
# FR3          10
# dtype: int64

# %%
feature_analysis('LandSlope')
# Out:
# There are 0 missing values in this column.
# Gtl    1396
# Mod      60
# Sev       3
# dtype: int64

# %%
feature_analysis('Neighborhood')
# Out:
# There are 0 missing values in this column.
# NAmes      218
# OldTown    126
# CollgCr    117
# Somerst     96
# Edwards     94
# NridgHt     89
# Gilbert     86
# Sawyer      77
# SawyerW     66
# Mitchel     65
# NWAmes      58
# IDOTRR      56
# Crawfor     52
# BrkSide     50
# Timber      34
# NoRidge     30
# StoneBr     26
# SWISU       23
# MeadowV     20
# ClearCr     16
# BrDale      14
# NPkVill     14
# Veenker     13
# Blmngtn     11
# Blueste      8
# dtype: int64

# %%
feature_analysis('HouseStyle')
# Out:
# There are 0 missing values in this column.
# 1Story    745
# 2Story    427
# 1.5Fin    160
# SLvl       63
# SFoyer     46
# 2.5Unf     13
# 1.5Unf      5
# dtype: int64

# %%
feature_analysis('YearBuilt')
# Out:
# There are 0 missing values in this column.
# 2005    78
# 2006    71
# 2007    60
# 2004    45
# 2003    43
# 1999    27
# 1920    27
# 2008    26
# 1910    26
# 1956    25
# 1967    25
# 1977    25
# 1958    24
# 2000    24
# 2002    24
# 1968    23
# 1978    23
# 1993    22
# 1998    21
# 1976    21
# 1997    21
# 1960    20
# 1961    20
# 1900    19
# 1963    19
# 1996    19
# 1954    19
# 1955    18
# 1964    18
# 1970    18
#         ..
# 1986     5
# 1987     5
# 1983     4
# 1942     4
# 1981     4
# 1929     4
# 1988     4
# 1937     4
# 1918     3
# 1895     3
# 1912     2
# 1905     2
# 1916     2
# 1901     2
# 2010     2
# 1917     2
# 1919     2
# 1928     2
# 1934     2
# 1936     2
# 1985     2
# 1914     1
# 1931     1
# 1907     1
# 1932     1
# 1902     1
# 1896     1
# 1982     1
# 1880     1
# 1879     1
# dtype: int64
# ---------------------------------------------------------------------------
# ...

# %%
ys = list(train_dataset['YearBuilt'].value_counts().index)

m_price = []
for i in ys:
    m_price.append(train_dataset['SalePrice'][train_dataset['YearBuilt']==i].median())
plt.scatter(ys, m_price)
plt.show()
pearsonr(ys,m_price)
# Out:
# (0.45648099369204892, 4.2241541570082848e-07)

# %%
print('There are {} missing values in this column.'
          .format(train_dataset['YearRemodAdd'].isnull().sum()))
ys = list(train_dataset['YearRemodAdd'].value_counts().index)

m_price = []
for i in ys:
    m_price.append(train_dataset['SalePrice'][train_dataset['YearRemodAdd']==i].median())
plt.scatter(train_dataset['YearRemodAdd'], train_dataset['SalePrice'])
plt.show()
pearsonr(ys,m_price)
# Out:
# There are 0 missing values in this column.
# (0.79521402573030808, 1.9495158564750119e-14)

# %%
feature_analysis('Exterior2nd')
# Out:
# There are 0 missing values in this column.
# VinylSd    510
# MetalSd    233
# HdBoard    199
# Wd Sdng    194
# Plywood    128
# CmentBd     66
# Wd Shng     43
# BrkFace     22
# Stucco      21
# AsbShng     18
# Brk Cmn     15
# ImStucc      5
# CBlock       2
# Stone        1
# AsphShn      1
# Name: Exterior2nd, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-8a63d2759eb0> in <module>()
# ----> 1 feature_analysis('Exterior2nd')
#
# <ipython-input-8-1a0ff02e3ce3> in feature_analysis(f_name)
#      19
#      20     for i in grps:
# ---> 21         train_dataset['SalePrice'][train_dataset[f_name]==i].plot(kind='density',label=i)
#      22     plt.legend()
#      23     plt.show()
#
# ...

# %%
#feature_analysis('1stFlrSF')
print('There are {} missing values in this column.'
          .format(train_dataset['ScreenPorch'].isnull().sum()))
ys = list(train_dataset['ScreenPorch'].value_counts().index)

m_price = []
for i in ys:
    m_price.append(train_dataset['SalePrice'][train_dataset['ScreenPorch']==i].median())
plt.scatter(ys,m_price)
plt.show()
pearsonr(ys,m_price)
# Out:
# There are 0 missing values in this column.
# (0.36234157110917226, 0.0012975487192481349)

# %%
#feature_analysis('MiscVal')
f_to_plot = [train_dataset['SalePrice'][train_dataset['MiscVal']==0],train_dataset['SalePrice'][train_dataset['MiscVal']!=0]]
fig = plt.figure(1, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(f_to_plot)
plt.show()

# %%
print('There are {} missing values in this column.'
          .format(test_dataset['PoolQC'].isnull().sum()))
print test_dataset.shape
# Out:
# There are 1456 missing values in this column.
# (1459, 80)

# %%
feature_analysis('SaleCondition')
# Out:
# There are 0 missing values in this column.
# Normal     1204
# Partial     120
# Abnorml      89
# Family       26
# Alloca       12
# AdjLand       8
# Name: SaleCondition, dtype: int64
